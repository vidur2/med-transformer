# %%
import pandas as pd

# %%
diag = pd.read_csv('./diagnoses_synth.csv')
enc = pd.read_csv('./encounters_synth_with_repeats.csv')
proc = pd.read_csv('./procedures_synth.csv')

# %%
# Group diagnoses by RECORD_ID and aggregate into lists
diag_grouped = diag.groupby('RECORD_ID').agg(lambda x: x.tolist()).reset_index()
diag_grouped.columns = ['RECORD_ID'] + [f'DIAGNOSIS_{col}' for col in diag_grouped.columns[1:]]

# Group procedures by RECORD_ID and aggregate into lists
proc_grouped = proc.groupby('RECORD_ID').agg(lambda x: x.tolist()).reset_index()
proc_grouped.columns = ['RECORD_ID'] + [f'PROCEDURE_{col}' for col in proc_grouped.columns[1:]]

# Join encounters with grouped diagnoses and procedures
final_df = enc.merge(diag_grouped[['RECORD_ID', 'DIAGNOSIS_RISK_VARIABLE_DESCRIPTION']], on='RECORD_ID', how='left')
final_df = final_df.merge(proc_grouped, on='RECORD_ID', how='left')

print(f"Final shape (one row per encounter): {final_df.shape}")
print(f"Number of encounters: {enc.shape[0]}")
final_df.head()
# Out:
# Final shape (one row per encounter): (2000, 97)
# Number of encounters: 2000
#   DATASET                            FACILITY_NAME              SHORTNAME  \
# 0   Focus                   WellStar Cobb Hospital          WELLSTAR_COBB
# 1   Focus                WellStar Douglas Hospital       WELLSTAR_DOUGLAS
# 2   Focus                   WellStar Cobb Hospital          WELLSTAR_COBB
# 3   Focus  WellStar Spalding Regional Hospital Inc      WELLSTAR_SPALDING
# 4   Focus       WellStar North Fulton Hospital Inc  WELLSTAR_NORTH_FULTON
#
#   VIZCOHORT VIZCOHORTLONG PEER_GROUP   RECORD_ID      PAITENT_ID  \
# 0      COMM          LSMC         CH  7000000795   3T2GQWMAC7.25
# 1      COMM          LCMC         CH  7000001468     I9XBI057.72
# 2      COMM          LSMC         CH  7000000478     IIWHJIMX.51
# 3      COMM          LCMC         CH  7000000807  GBMEKWVHAIQ.77
# 4      COMM          LCMC         CH  7000001505  36OQFCPUDOX.81
#
#    ENCOUNTER_ID ADMISSION_DATE  ... RV_THROMBOCYTOPENIA  RV_CHRONIC_FATIGUE  \
# 0  7.429665e+12     2025-10-17  ...                   0                   0
# 1  6.561768e+12     2025-10-17  ...                   0                   0
# 2  5.557538e+11     2025-10-16  ...                   0                   0
# 3  8.296730e+12     2025-10-12  ...                   0                   0
# 4  2.399520e+12     2025-10-17  ...                   0                   0
#
#    SUBSTANCE_ABUSE  ENC_COUNT           DIAGNOSIS_RISK_VARIABLE_DESCRIPTION  \
# 0                0          1                          [nan, nan, nan, nan]
# 1                0          1                                         [nan]
# 2                1          1      [any fluid electrolyte, Lipid Disorders]
# 3                0          1  [NPOA DIC, nan, nan, NPOA Malnutrition, nan]
# 4                0          1                          [nan, Liver Failure]
#
#       PROCEDURE_PROCEDURE_CODE  PROCEDURE_SEQUENCE_NUMBER  \
# 0           [30233N1, 0W9G3ZZ]                     [1, 2]
# 1                          NaN                        NaN
# 2  [30243N1, 0W3P0ZZ, 30233N1]                  [1, 2, 3]
# 3           [0W9G3ZZ, B2111ZZ]                     [1, 2]
# 4           [5A1955Z, 0DBP8ZX]                     [1, 2]
#
#                PROCEDURE_PROCEDURE_DATE  \
# 0              [2025-10-18, 2025-10-17]
# 1                                   NaN
# 2  [2025-10-18, 2025-10-18, 2025-10-17]
# 3              [2025-10-12, 2025-10-12]
# 4              [2025-10-18, 2025-10-18]
#
#                             PROCEDURE_PROCEDURE_NAME  \
# 0  [Transfusion of nonautologous red blood cells ...
# 1                                                NaN
# 2  [Transfusion of nonautologous red blood cells ...
# 3  [Drainage of thoracic cavity, percutaneous app...
# 4  [Respiratory ventilation, 24–96 consecutive ho...
#
#                       PROCEDURE_VARIABLE_DESCRIPTION
# 0  [Control Bleeding on Admission Day, Respirator...
# 1                                                NaN
# 2  [nan, Control Bleeding on Admission Day, Contr...
# 3      [Respiratory Support, Hemodynamic Monitoring]
# 4                             [Vent within 48h, nan]
#
# [5 rows x 97 columns]

# %%
# Check column names to find patient ID and encounter date columns
enc.columns
# Out:
# Index(['DATASET', 'FACILITY_NAME', 'SHORTNAME', 'VIZCOHORT', 'VIZCOHORTLONG',
#        'PEER_GROUP', 'RECORD_ID', 'PAITENT_ID', 'ENCOUNTER_ID',
#        'ADMISSION_DATE', 'DISCHARGE_DATE', 'DISCH_YEAR', 'DISCH_MONTH',
#        'ADMISSION_AGE_YEARS', 'ADMISSION_SOURCE_CODE',
#        'ADMISSION_STATUS_DESCRIPTION', 'ADMISSION_STATUS_CODE',
#        'ADMISSION_SOURCE_DESCRIPTION', 'DISCHARGE_STATUS_CODE',
#        'VIZ_MSDRG_CODE', 'VIZ_MSDRG_DESCRIPTION', 'CMI', 'VIZ_BASEMSDRG_CODE',
#        'VIZ_BASEMSDRG_DESCRIPTION', 'LOS', 'ICU_DAYS', 'LOS_OUTLIER',
#        'DEATH_FLAG', 'RACE', 'ETHNICITY', 'SEX', 'READMIT_NUM',
#        'READMIT_DENOM', 'DAYS_TO_READMIT', 'OBSERVED_DIRECT_COST',
#        'COST_TYPE_CODE', 'RISK_TYPE_CODE', 'EXPECTED_LOS',
#        'EXPECTED_MORTALITY', 'EXPECTED_DIRECT_COST',
#        'RELATIVE_EXPECTED_MORTALITY', 'RELATIVE_EXPECTED_LOS',
#        'RELATIVE_EXPECTED_DIRECT_COST', 'VIZ_ACUITY_SCALE_MORTALITY',
#        'VIZ_ACUITY_SCALE_DIRECT_COST', 'VIZ_ACUITY_SCALE_LOS',
#        'VIZ_SERVICE_LINE_CODE', 'VIZ_SUB_SERVICE_LINE_CODE',
#        'VIZ_SERVICE_LINE_DESCRIPTION', 'VIZ_SUB_SERVICE_LINE_DESCRIPTION',
#        'SERVICE_LINE_VERSION', 'PRIMARY_DIAGNOSIS_CODE',
#        'PRIMARY_DIAGNOSIS_DESCRIPTION', 'PRIMARY_DIAGNOSIS',
#        'PRIMARY_PROCEDURE_CODE', 'PRIMARY_PROCEDURE_DESCRIPTION',
#        'PRIMARY_PROCEDURE', 'MORTALITY_QA_SERVICE_LINE', 'LOS_QA_SERVICE_LINE',
#        'READMIT_QA_SERVICE_LINE', 'NONVIABLE_NEONATE_FLAG',
#        'NORMAL_NEWBORN_FLAG', 'HOSPICE_FLAG', 'PLANNED_ADMISSION_FLAG',
#        'TRANSFER_IN_FLAG', 'PALLIATIVE_CARE_FLAG', 'RV_ADMIT_ED_TRAUMA',
#        'DISCHARGE_TO_HOSPICE_FLAG', 'RV_TXFER_ACUTE', 'DNR_WO_VENT_ECMO_FLAG',
#        'RV_VENT_ON_ADMIT_DATE', 'RV_FLUID_ELECTROLYTE_DISORDERS',
#        'RV_MALNUTRITION', 'RV_CHF', 'RV_SHOCK', 'RV_CACHEXIA',
#        'RV_COAGULATION_DEFECT', 'RV_METASTATIC_CANCER', 'RV_LIVER_FAILURE',
#        'RV_RESPIRATORY_FAILURE', 'RV_ACUTE_RENAL_FAILURE',
#        'RV_NUTRITIONAL_ANEMIA', 'RV_OBESITY', 'RV_ANEMIA_IN_CHRONIC_DISEASE',
#        'RV_DEMENTIA', 'RV_BLOOD_LOSS_ANEMIA', 'RV_ANEMIA',
#        'RV_THROMBOCYTOPENIA', 'RV_CHRONIC_FATIGUE', 'SUBSTANCE_ABUSE',
#        'ENC_COUNT'],
#       dtype='object')

# %%
# Sort by PATIENT_ID and ENCOUNTER_DATE ascending
final_df_sorted = final_df.sort_values(by=['PAITENT_ID', 'ADMISSION_DATE'], ascending=[True, True])
print(f"Sorted dataframe shape: {final_df_sorted.shape}")
final_df_sorted.head(10)
# Out:
# Sorted dataframe shape: (2000, 97)
#      DATASET                            FACILITY_NAME            SHORTNAME  \
# 5      Focus                   WellStar Cobb Hospital        WELLSTAR_COBB
# 1670   Focus  WellStar Spalding Regional Hospital Inc    WELLSTAR_SPALDING
# 1073   Focus                   WellStar Cobb Hospital        WELLSTAR_COBB
# 853    Focus                   WellStar Cobb Hospital        WELLSTAR_COBB
# 309    Focus                   WellStar Cobb Hospital        WELLSTAR_COBB
# 1524   Focus                WellStar Douglas Hospital     WELLSTAR_DOUGLAS
# 432    Focus                WellStar Douglas Hospital     WELLSTAR_DOUGLAS
# 1232   Focus                      WellStar MCG Health  WELLSTAR_MCG_HEALTH
# 885    Focus                   WellStar Cobb Hospital        WELLSTAR_COBB
# 130    Focus                   WellStar Cobb Hospital        WELLSTAR_COBB
#
#      VIZCOHORT VIZCOHORTLONG PEER_GROUP   RECORD_ID      PAITENT_ID  \
# 5         COMM          LSMC         CH  7000001279   00K4N4OD1B.77
# 1670      COMM          LCMC         CH  7000000824   00K4N4OD1B.77
# 1073      COMM          LSMC         CH  7000001167   00K4N4OD1B.77
# 853       COMM          LSMC         CH  7000000722    026PQWG41WKM
# 309       COMM          LSMC         CH  7000000544  04ZK03LE6FV.77
# 1524      COMM          LCMC         CH  7000000557  04ZK03LE6FV.77
# 432       COMM          LCMC         CH  7000001193  04ZK03LE6FV.77
# 1232       AMC           AMC        AMC  7000001843        051S0OAN
# 885       COMM          LSMC         CH  7000001710        051S0OAN
# 130       COMM          LSMC         CH  7000000187     09YYT1CSP6C
#
#       ENCOUNTER_ID ADMISSION_DATE  ... RV_THROMBOCYTOPENIA  \
# 5     2.363958e+12     2025-10-13  ...                   0
# 1670  1.008630e+12     2025-10-21  ...                   0
# 1073  7.475995e+12     2025-10-22  ...                   0
# 853   2.770188e+12     2025-10-20  ...                   0
# 309   8.990034e+12     2025-10-02  ...                   0
# 1524  5.142703e+12     2025-10-15  ...                   0
# 432   9.020782e+12     2025-10-24  ...                   0
# 1232  6.766635e+12     2025-10-17  ...                   0
# 885   3.954687e+12     2025-10-21  ...                   0
# 130   7.722571e+12     2025-10-03  ...                   0
#
#       RV_CHRONIC_FATIGUE  SUBSTANCE_ABUSE  ENC_COUNT  \
# 5                      0                0          1
# 1670                   0                0          1
# 1073                   0                0          1
# 853                    0                1          1
# 309                    0                1          1
# 1524                   0                0          1
# 432                    0                0          1
# 1232                   0                0          1
# 885                    0                0          1
# 130                    0                0          1
#
#                     DIAGNOSIS_RISK_VARIABLE_DESCRIPTION  \
# 5                            [nan, Acute Renal Failure]
# 1670      [Liver Failure, nan, nan, nan, nan, Dementia]
# 1073                  [any fluid electrolyte, nan, nan]
# 853   [nan, Metastatic Cancer, Respiratory Failure, ...
# 309                                               [nan]
# 1524      [nan, CHF, Acute Renal Failure, nan, Obesity]
# 432    [Respiratory Failure, Lipid Disorders, Dementia]
# 1232  [any fluid electrolyte, any fluid electrolyte,...
# 885      [nan, nan, nan, Obesity, nan, Lipid Disorders]
# 130                    [nan, Lipid Disorders, nan, nan]
#
#                   PROCEDURE_PROCEDURE_CODE  PROCEDURE_SEQUENCE_NUMBER  \
# 5              [B211YZZ, 5A1945Z, 3E03329]                  [1, 2, 3]
# 1670                    [0DBP8ZX, 3E03329]                     [1, 2]
# 1073                                   NaN                        NaN
# 853            [30243N1, 30233N1, 5A1D70Z]                  [1, 2, 3]
# 309                              [0W3P0ZZ]                        [1]
# 1524  [30243N1, 5A1955Z, 0W9G3ZZ, 3E03329]               [1, 2, 3, 4]
# 432            [0DBP8ZX, 30233N1, 0W9G3ZZ]                  [1, 2, 3]
# 1232           [B211YZZ, 5A1955Z, 30243N1]                  [1, 2, 3]
# 885   [30243N1, B211YZZ, 5A1955Z, 5A1945Z]               [1, 2, 3, 4]
# 130                                    NaN                        NaN
#
#                               PROCEDURE_PROCEDURE_DATE  \
# 5                 [2025-10-14, 2025-10-13, 2025-10-13]
# 1670                          [2025-10-22, 2025-10-21]
# 1073                                               NaN
# 853               [2025-10-21, 2025-10-24, 2025-10-20]
# 309                                       [2025-10-03]
# 1524  [2025-10-15, 2025-10-15, 2025-10-15, 2025-10-15]
# 432               [2025-10-27, 2025-10-30, 2025-10-24]
# 1232              [2025-10-17, 2025-10-20, 2025-10-18]
# 885   [2025-10-22, 2025-10-25, 2025-10-25, 2025-10-24]
# 130                                                NaN
#
#                                PROCEDURE_PROCEDURE_NAME  \
# 5     [Measurement of cardiac pressure, monitoring, ...
# 1670  [Diagnostic excision of large intestine, via n...
# 1073                                                NaN
# 853   [Transfusion of nonautologous red blood cells ...
# 309   [Control bleeding in upper gastrointestinal tr...
# 1524  [Transfusion of nonautologous red blood cells ...
# 432   [Diagnostic excision of large intestine, via n...
# 1232  [Measurement of cardiac pressure, monitoring, ...
# 885   [Transfusion of nonautologous red blood cells ...
# 130                                                 NaN
#
#                          PROCEDURE_VARIABLE_DESCRIPTION
# 5     [Hemodynamic Monitoring, Vent on Admission Day...
# 1670                       [nan, IV Antibiotic Therapy]
# 1073                                                NaN
# 853   [nan, Control Bleeding on Admission Day, Hemod...
# 309                 [Control Bleeding on Admission Day]
# 1524  [nan, Vent within 48h, Respiratory Support, IV...
# 432       [nan, Control Bleeding on Admission Day, nan]
# 1232     [Hemodynamic Monitoring, Vent within 48h, nan]
# 885   [nan, nan, Vent within 48h, Vent on Admission ...
# 130                                                 NaN
#
# [10 rows x 97 columns]

# %%
# Calculate the number of encounters (sequence length) per patient
encounters_per_patient = final_df_sorted.groupby('PAITENT_ID').size()

# Calculate statistics
avg_sequence_length = encounters_per_patient.mean()
median_sequence_length = encounters_per_patient.median()
min_sequence_length = encounters_per_patient.min()
max_sequence_length = encounters_per_patient.max()

print(f"Average sequence length per patient: {avg_sequence_length:.2f}")
print(f"Median sequence length per patient: {median_sequence_length:.0f}")
print(f"Min sequence length: {min_sequence_length}")
print(f"Max sequence length: {max_sequence_length}")
print(f"\nDistribution of sequence lengths:")
print(encounters_per_patient.value_counts().sort_index())
# Out:
# Average sequence length per patient: 2.99
# Median sequence length per patient: 3
# Min sequence length: 1
# Max sequence length: 5
#
# Distribution of sequence lengths:
# 1     42
# 2    168
# 3    244
# 4    180
# 5     34
# Name: count, dtype: int64

# %%
final_df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 5 to 492
# Data columns (total 97 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   DATASET                              2000 non-null   object
#  1   FACILITY_NAME                        2000 non-null   object
#  2   SHORTNAME                            2000 non-null   object
#  3   VIZCOHORT                            2000 non-null   object
#  4   VIZCOHORTLONG                        2000 non-null   object
#  5   PEER_GROUP                           2000 non-null   object
#  6   RECORD_ID                            2000 non-null   int64
#  7   PAITENT_ID                           2000 non-null   object
#  8   ENCOUNTER_ID                         2000 non-null   float64
#  9   ADMISSION_DATE                       2000 non-null   object
#  10  DISCHARGE_DATE                       2000 non-null   object
#  11  DISCH_YEAR                           2000 non-null   int64
#  12  DISCH_MONTH                          2000 non-null   int64
#  13  ADMISSION_AGE_YEARS                  2000 non-null   int64
#  14  ADMISSION_SOURCE_CODE                2000 non-null   int64
#  15  ADMISSION_STATUS_DESCRIPTION         2000 non-null   object
#  16  ADMISSION_STATUS_CODE                2000 non-null   int64
#  17  ADMISSION_SOURCE_DESCRIPTION         2000 non-null   object
#  18  DISCHARGE_STATUS_CODE                2000 non-null   int64
#  19  VIZ_MSDRG_CODE                       2000 non-null   int64
#  20  VIZ_MSDRG_DESCRIPTION                2000 non-null   object
#  21  CMI                                  2000 non-null   float64
#  22  VIZ_BASEMSDRG_CODE                   2000 non-null   int64
#  23  VIZ_BASEMSDRG_DESCRIPTION            2000 non-null   object
#  24  LOS                                  2000 non-null   int64
#  25  ICU_DAYS                             2000 non-null   int64
#  26  LOS_OUTLIER                          2000 non-null   int64
#  27  DEATH_FLAG                           2000 non-null   int64
#  28  RACE                                 2000 non-null   object
#  29  ETHNICITY                            2000 non-null   object
#  30  SEX                                  2000 non-null   object
#  31  READMIT_NUM                          460 non-null    float64
#  32  READMIT_DENOM                        284 non-null    float64
#  33  DAYS_TO_READMIT                      248 non-null    float64
#  34  OBSERVED_DIRECT_COST                 2000 non-null   float64
#  35  COST_TYPE_CODE                       2000 non-null   int64
#  36  RISK_TYPE_CODE                       2000 non-null   int64
#  37  EXPECTED_LOS                         2000 non-null   float64
#  38  EXPECTED_MORTALITY                   2000 non-null   float64
#  39  EXPECTED_DIRECT_COST                 2000 non-null   float64
#  40  RELATIVE_EXPECTED_MORTALITY          2000 non-null   float64
#  41  RELATIVE_EXPECTED_LOS                2000 non-null   float64
#  42  RELATIVE_EXPECTED_DIRECT_COST        2000 non-null   float64
#  43  VIZ_ACUITY_SCALE_MORTALITY           2000 non-null   object
#  44  VIZ_ACUITY_SCALE_DIRECT_COST         2000 non-null   object
#  45  VIZ_ACUITY_SCALE_LOS                 2000 non-null   object
#  46  VIZ_SERVICE_LINE_CODE                2000 non-null   int64
#  47  VIZ_SUB_SERVICE_LINE_CODE            2000 non-null   object
#  48  VIZ_SERVICE_LINE_DESCRIPTION         2000 non-null   object
#  49  VIZ_SUB_SERVICE_LINE_DESCRIPTION     2000 non-null   object
#  50  SERVICE_LINE_VERSION                 2000 non-null   object
#  51  PRIMARY_DIAGNOSIS_CODE               1831 non-null   object
#  52  PRIMARY_DIAGNOSIS_DESCRIPTION        1831 non-null   object
#  53  PRIMARY_DIAGNOSIS                    1831 non-null   object
#  54  PRIMARY_PROCEDURE_CODE               1393 non-null   object
#  55  PRIMARY_PROCEDURE_DESCRIPTION        1393 non-null   object
#  56  PRIMARY_PROCEDURE                    1393 non-null   object
#  57  MORTALITY_QA_SERVICE_LINE            2000 non-null   bool
#  58  LOS_QA_SERVICE_LINE                  2000 non-null   bool
#  59  READMIT_QA_SERVICE_LINE              2000 non-null   bool
#  60  NONVIABLE_NEONATE_FLAG               2000 non-null   int64
#  61  NORMAL_NEWBORN_FLAG                  2000 non-null   int64
#  62  HOSPICE_FLAG                         2000 non-null   int64
#  63  PLANNED_ADMISSION_FLAG               2000 non-null   int64
#  64  TRANSFER_IN_FLAG                     2000 non-null   int64
#  65  PALLIATIVE_CARE_FLAG                 2000 non-null   int64
#  66  RV_ADMIT_ED_TRAUMA                   2000 non-null   int64
#  67  DISCHARGE_TO_HOSPICE_FLAG            2000 non-null   int64
#  68  RV_TXFER_ACUTE                       2000 non-null   int64
#  69  DNR_WO_VENT_ECMO_FLAG                2000 non-null   int64
#  70  RV_VENT_ON_ADMIT_DATE                2000 non-null   int64
#  71  RV_FLUID_ELECTROLYTE_DISORDERS       2000 non-null   int64
#  72  RV_MALNUTRITION                      2000 non-null   int64
#  73  RV_CHF                               2000 non-null   int64
#  74  RV_SHOCK                             2000 non-null   int64
#  75  RV_CACHEXIA                          2000 non-null   int64
#  76  RV_COAGULATION_DEFECT                2000 non-null   int64
#  77  RV_METASTATIC_CANCER                 2000 non-null   int64
#  78  RV_LIVER_FAILURE                     2000 non-null   int64
#  79  RV_RESPIRATORY_FAILURE               2000 non-null   int64
#  80  RV_ACUTE_RENAL_FAILURE               2000 non-null   int64
#  81  RV_NUTRITIONAL_ANEMIA                2000 non-null   int64
#  82  RV_OBESITY                           2000 non-null   int64
#  83  RV_ANEMIA_IN_CHRONIC_DISEASE         2000 non-null   int64
#  84  RV_DEMENTIA                          2000 non-null   int64
#  85  RV_BLOOD_LOSS_ANEMIA                 2000 non-null   int64
#  86  RV_ANEMIA                            2000 non-null   int64
#  87  RV_THROMBOCYTOPENIA                  2000 non-null   int64
#  88  RV_CHRONIC_FATIGUE                   2000 non-null   int64
#  89  SUBSTANCE_ABUSE                      2000 non-null   int64
#  90  ENC_COUNT                            2000 non-null   int64
#  91  DIAGNOSIS_RISK_VARIABLE_DESCRIPTION  2000 non-null   object
#  92  PROCEDURE_PROCEDURE_CODE             1484 non-null   object
#  93  PROCEDURE_SEQUENCE_NUMBER            1484 non-null   object
#  94  PROCEDURE_PROCEDURE_DATE             1484 non-null   object
#  95  PROCEDURE_PROCEDURE_NAME             1484 non-null   object
#  96  PROCEDURE_VARIABLE_DESCRIPTION       1484 non-null   object
# dtypes: bool(3), float64(12), int64(47), object(35)
# memory usage: 1.5+ MB

# %%
final_df.dtypes
# Out:
# DATASET                           object
# FACILITY_NAME                     object
# SHORTNAME                         object
# VIZCOHORT                         object
# VIZCOHORTLONG                     object
#                                    ...
# PROCEDURE_PROCEDURE_CODE          object
# PROCEDURE_SEQUENCE_NUMBER         object
# PROCEDURE_PROCEDURE_DATE          object
# PROCEDURE_PROCEDURE_NAME          object
# PROCEDURE_VARIABLE_DESCRIPTION    object
# Length: 97, dtype: object

# %%
# Check all columns and their types in final_df_sorted
print("Columns in final_df_sorted:")
for i, col in enumerate(final_df_sorted.columns):
    dtype = final_df_sorted[col].dtype
    sample_val = final_df_sorted[col].iloc[0] if len(final_df_sorted) > 0 else None
    print(f"{col}: {dtype} (sample: {sample_val})")
    
print(f"\nTotal columns: {len(final_df_sorted.columns)}")

# Check unique values in RISK_VARIABLE_DESCRIPTION
print(f"\nUnique RISK_VARIABLE_DESCRIPTION values: {diag['RISK_VARIABLE_DESCRIPTION']}")
print("Sample values:")
print(diag['RISK_VARIABLE_DESCRIPTION'].value_counts().head(10))
# Out:
# Columns in final_df_sorted:
# DATASET: object (sample: Focus)
# FACILITY_NAME: object (sample: WellStar Cobb Hospital)
# SHORTNAME: object (sample: WELLSTAR_COBB)
# VIZCOHORT: object (sample: COMM)
# VIZCOHORTLONG: object (sample: LSMC)
# PEER_GROUP: object (sample: CH)
# RECORD_ID: int64 (sample: 7000001279)
# PAITENT_ID: object (sample: 00K4N4OD1B.77)
# ENCOUNTER_ID: float64 (sample: 2363958054440.0)
# ADMISSION_DATE: object (sample: 2025-10-13)
# DISCHARGE_DATE: object (sample: 2025-10-14)
# DISCH_YEAR: int64 (sample: 2025)
# DISCH_MONTH: int64 (sample: 10)
# ADMISSION_AGE_YEARS: int64 (sample: 66)
# ADMISSION_SOURCE_CODE: int64 (sample: 3)
# ADMISSION_STATUS_DESCRIPTION: object (sample: Elective)
# ADMISSION_STATUS_CODE: int64 (sample: 3)
# ADMISSION_SOURCE_DESCRIPTION: object (sample: Transfer from a hospital)
# DISCHARGE_STATUS_CODE: int64 (sample: 1)
# VIZ_MSDRG_CODE: int64 (sample: 280)
# VIZ_MSDRG_DESCRIPTION: object (sample: Acute myocardial infarction, discharged alive with MCC)
# CMI: float64 (sample: 1.3)
# VIZ_BASEMSDRG_CODE: int64 (sample: 280)
# VIZ_BASEMSDRG_DESCRIPTION: object (sample: Acute myocardial infarction)
# LOS: int64 (sample: 2)
# ICU_DAYS: int64 (sample: 0)
# LOS_OUTLIER: int64 (sample: 0)
# DEATH_FLAG: int64 (sample: 0)
# RACE: object (sample: Black)
# ETHNICITY: object (sample: Non Hispanic Origin)
# SEX: object (sample: Female)
# READMIT_NUM: float64 (sample: nan)
# READMIT_DENOM: float64 (sample: nan)
# DAYS_TO_READMIT: float64 (sample: nan)
# OBSERVED_DIRECT_COST: float64 (sample: 2963.31)
# COST_TYPE_CODE: int64 (sample: 3)
# RISK_TYPE_CODE: int64 (sample: 1)
# EXPECTED_LOS: float64 (sample: 2.99)
# EXPECTED_MORTALITY: float64 (sample: 0.0547)
# EXPECTED_DIRECT_COST: float64 (sample: 3234.86)
# RELATIVE_EXPECTED_MORTALITY: float64 (sample: 0.37)
# RELATIVE_EXPECTED_LOS: float64 (sample: 0.67)
# RELATIVE_EXPECTED_DIRECT_COST: float64 (sample: 0.92)
# VIZ_ACUITY_SCALE_MORTALITY: object (sample: Well Below)
# VIZ_ACUITY_SCALE_DIRECT_COST: object (sample: Slightly Below)
# VIZ_ACUITY_SCALE_LOS: object (sample: Well Below)
# VIZ_SERVICE_LINE_CODE: int64 (sample: 9)
# VIZ_SUB_SERVICE_LINE_CODE: object (sample: 9c)
# VIZ_SERVICE_LINE_DESCRIPTION: object (sample: Cardiology — Ischemic Heart Disease)
# VIZ_SUB_SERVICE_LINE_DESCRIPTION: object (sample: Cardiology — AMI)
# SERVICE_LINE_VERSION: object (sample: 2025Q4)
# PRIMARY_DIAGNOSIS_CODE: object (sample: G3183)
# PRIMARY_DIAGNOSIS_DESCRIPTION: object (sample: Dementia with Lewy bodies)
# PRIMARY_DIAGNOSIS: object (sample: Neurocognitive disorder with Lewy bodies)
# PRIMARY_PROCEDURE_CODE: object (sample: 0DBP8ZX)
# PRIMARY_PROCEDURE_DESCRIPTION: object (sample: Diagnostic excision of large intestine, via natural or artificial opening endoscopic)
# PRIMARY_PROCEDURE: object (sample: Diagnostic excision of large intestine, via natural or artificial opening endoscopic)
# MORTALITY_QA_SERVICE_LINE: bool (sample: True)
# LOS_QA_SERVICE_LINE: bool (sample: False)
# READMIT_QA_SERVICE_LINE: bool (sample: False)
# NONVIABLE_NEONATE_FLAG: int64 (sample: 0)
# NORMAL_NEWBORN_FLAG: int64 (sample: 0)
# HOSPICE_FLAG: int64 (sample: 0)
# PLANNED_ADMISSION_FLAG: int64 (sample: 1)
# TRANSFER_IN_FLAG: int64 (sample: 1)
# PALLIATIVE_CARE_FLAG: int64 (sample: 0)
# RV_ADMIT_ED_TRAUMA: int64 (sample: 0)
# DISCHARGE_TO_HOSPICE_FLAG: int64 (sample: 0)
# RV_TXFER_ACUTE: int64 (sample: 0)
# DNR_WO_VENT_ECMO_FLAG: int64 (sample: 0)
# RV_VENT_ON_ADMIT_DATE: int64 (sample: 0)
# RV_FLUID_ELECTROLYTE_DISORDERS: int64 (sample: 0)
# RV_MALNUTRITION: int64 (sample: 0)
# RV_CHF: int64 (sample: 0)
# RV_SHOCK: int64 (sample: 0)
# RV_CACHEXIA: int64 (sample: 0)
# RV_COAGULATION_DEFECT: int64 (sample: 0)
# RV_METASTATIC_CANCER: int64 (sample: 0)
# RV_LIVER_FAILURE: int64 (sample: 0)
# RV_RESPIRATORY_FAILURE: int64 (sample: 0)
# RV_ACUTE_RENAL_FAILURE: int64 (sample: 0)
# RV_NUTRITIONAL_ANEMIA: int64 (sample: 0)
# RV_OBESITY: int64 (sample: 1)
# RV_ANEMIA_IN_CHRONIC_DISEASE: int64 (sample: 0)
# RV_DEMENTIA: int64 (sample: 1)
# RV_BLOOD_LOSS_ANEMIA: int64 (sample: 0)
# RV_ANEMIA: int64 (sample: 0)
# RV_THROMBOCYTOPENIA: int64 (sample: 0)
# RV_CHRONIC_FATIGUE: int64 (sample: 0)
# SUBSTANCE_ABUSE: int64 (sample: 0)
# ENC_COUNT: int64 (sample: 1)
# DIAGNOSIS_RISK_VARIABLE_DESCRIPTION: object (sample: [nan, 'Acute Renal Failure'])
# PROCEDURE_PROCEDURE_CODE: object (sample: ['B211YZZ', '5A1945Z', '3E03329'])
# PROCEDURE_SEQUENCE_NUMBER: object (sample: [1, 2, 3])
# PROCEDURE_PROCEDURE_DATE: object (sample: ['2025-10-14', '2025-10-13', '2025-10-13'])
# PROCEDURE_PROCEDURE_NAME: object (sample: ['Measurement of cardiac pressure, monitoring, via peripheral approach', 'Respiratory ventilation, less than 24 consecutive hours', 'Introduction of other anti-infective into peripheral vein, percutaneous approach'])
# PROCEDURE_VARIABLE_DESCRIPTION: object (sample: ['Hemodynamic Monitoring', 'Vent on Admission Day', 'IV Antibiotic Therapy'])
#
# Total columns: 97
#
# Unique RISK_VARIABLE_DESCRIPTION values: 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#               ...
# 5956                  NaN
# 5957                  NaN
# 5958    Metastatic Cancer
# 5959                  NaN
# 5960    Metastatic Cancer
# Name: RISK_VARIABLE_DESCRIPTION, Length: 5961, dtype: object
# Sample values:
# RISK_VARIABLE_DESCRIPTION
# any fluid electrolyte     764
# Lipid Disorders           653
# Obesity                   341
# any Blood Loss Anemia     173
# Metastatic Cancer         152
# NPOA DIC                  151
# Anticoagulation Status    146
# Liver Failure             145
# NPOA Malnutrition         142
# RV Thrombocytopenia       142
# Name: count, dtype: int64

# %%
# Convert date columns to datetime and calculate length of stay
final_df['ADMISSION_DATE'] = pd.to_datetime(final_df['ADMISSION_DATE'])
final_df['DISCHARGE_DATE'] = pd.to_datetime(final_df['DISCHARGE_DATE'])

# Calculate day difference
final_df['LENGTH_OF_STAY_DAYS'] = (final_df['DISCHARGE_DATE'] - final_df['ADMISSION_DATE']).dt.days

print(f"Length of stay statistics:")
print(f"  Mean: {final_df['LENGTH_OF_STAY_DAYS'].mean():.2f} days")
print(f"  Median: {final_df['LENGTH_OF_STAY_DAYS'].median():.0f} days")
print(f"  Min: {final_df['LENGTH_OF_STAY_DAYS'].min()} days")
print(f"  Max: {final_df['LENGTH_OF_STAY_DAYS'].max()} days")

final_df[['ADMISSION_DATE', 'DISCHARGE_DATE', 'LENGTH_OF_STAY_DAYS']].head()
# Out:
# Length of stay statistics:
#   Mean: 3.43 days
#   Median: 2 days
#   Min: 0 days
#   Max: 23 days
#   ADMISSION_DATE DISCHARGE_DATE  LENGTH_OF_STAY_DAYS
# 0     2025-10-17     2025-10-18                    1
# 1     2025-10-17     2025-10-17                    0
# 2     2025-10-16     2025-10-18                    2
# 3     2025-10-12     2025-10-12                    0
# 4     2025-10-17     2025-10-18                    1

# %%
# Save the structured dataframe to JSON
output_file = 'processed_structured.json'

print(f"Saving structured data to {output_file}...")
final_df_structured.to_json(output_file, orient='records', indent=2, date_format='iso')

print(f"✓ Saved {len(final_df_structured)} records to {output_file}")

# Show statistics
print("\n" + "=" * 80)
print("STATISTICS")
print("=" * 80)

if 'procedures' in final_df_structured.columns:
    proc_counts = final_df_structured['procedures'].apply(len)
    print(f"\nProcedures per encounter:")
    print(f"  Mean: {proc_counts.mean():.2f}")
    print(f"  Median: {proc_counts.median():.0f}")
    print(f"  Min: {proc_counts.min()}")
    print(f"  Max: {proc_counts.max()}")

print(f"\nTotal records: {len(final_df_structured)}")
print(f"Total columns: {len(final_df_structured.columns)}")

def restructure_procedures(row):
    """
    Extract PROCEDURE_* columns and restructure them as a list of procedure objects.
    """
    procedure_fields = {}
    
    # Find all PROCEDURE_* columns
    for col in row.index:
        if col.startswith('PROCEDURE_'):
            field_name = col.replace('PROCEDURE_', '').lower()
            value = row[col]
            # Handle list values
            if isinstance(value, list):
                procedure_fields[field_name] = value
            else:
                procedure_fields[field_name] = [value] if pd.notna(value) else []
    
    if not procedure_fields:
        return []
    
    # Determine the maximum length across all procedure fields
    max_length = max(len(v) for v in procedure_fields.values()) if procedure_fields else 0
    
    if max_length == 0:
        return []
    
    # Create list of procedure objects
    procedures = []
    for i in range(max_length):
        procedure_obj = {}
        for field_name, values in procedure_fields.items():
            # Use the value at index i, or None if the list is shorter
            value = values[i] if i < len(values) else None
            procedure_obj[field_name] = value
        procedures.append(procedure_obj)
    
    return procedures


def restructure_diagnoses(row):
    """
    Extract DIAGNOSIS_* columns and restructure them as a list of diagnosis objects.
    """
    diagnosis_fields = {}
    
    # Find all DIAGNOSIS_* columns
    for col in row.index:
        if col.startswith('DIAGNOSIS_'):
            field_name = col.replace('DIAGNOSIS_', '').lower()
            value = row[col]
            # Handle list values
            if isinstance(value, list):
                diagnosis_fields[field_name] = value
            else:
                diagnosis_fields[field_name] = [value] if pd.notna(value) else []
    
    if not diagnosis_fields:
        return []
    
    # Determine the maximum length across all diagnosis fields
    max_length = max(len(v) for v in diagnosis_fields.values()) if diagnosis_fields else 0
    
    if max_length == 0:
        return []
    
    # Create list of diagnosis objects
    diagnoses = []
    for i in range(max_length):
        diagnosis_obj = {}
        for field_name, values in diagnosis_fields.items():
            # Use the value at index i, or None if the list is shorter
            value = values[i] if i < len(values) else None
            diagnosis_obj[field_name] = value
        diagnoses.append(diagnosis_obj)
    
    return diagnoses


# Apply restructuring
print("Restructuring procedures...")
final_df['procedures'] = final_df.apply(restructure_procedures, axis=1)

# Drop the original PROCEDURE_* and DIAGNOSIS_* columns
procedure_cols = [col for col in final_df.columns if col.startswith('PROCEDURE_')]
diagnosis_cols = [col for col in final_df.columns if col.startswith('DIAGNOSIS_') if 'RISK_VARIABLE_DESCRIPTION' not in col]

print(f"\nDropping {len(procedure_cols)} PROCEDURE_* columns")
print(f"Dropping {len(diagnosis_cols)} DIAGNOSIS_* columns")

final_df_structured = final_df.drop(columns=procedure_cols + diagnosis_cols)

print(f"\nFinal shape: {final_df_structured.shape}")
print(f"Final columns: {list(final_df_structured.columns)}")

# Show sample
print("\nSample structured row:")
sample_row = final_df_structured.iloc[0].to_dict()
print(json.dumps(sample_row, indent=2, default=str))
# Out:
# Saving structured data to processed_structured.json...
# ✓ Saved 2000 records to processed_structured.json
#
# ================================================================================
# STATISTICS
# ================================================================================
#
# Procedures per encounter:
#   Mean: 1.74
#   Median: 2
#   Min: 0
#   Max: 5
#
# Total records: 2000
# Total columns: 94
# Restructuring procedures...
#
# Dropping 5 PROCEDURE_* columns
# Dropping 1 DIAGNOSIS_* columns
#
# Final shape: (2000, 93)
# Final columns: ['DATASET', 'FACILITY_NAME', 'SHORTNAME', 'VIZCOHORT', 'VIZCOHORTLONG', 'PEER_GROUP', 'RECORD_ID', 'PAITENT_ID', 'ENCOUNTER_ID', 'ADMISSION_DATE', 'DISCHARGE_DATE', 'DISCH_YEAR', 'DISCH_MONTH', 'ADMISSION_AGE_YEARS', 'ADMISSION_SOURCE_CODE', 'ADMISSION_STATUS_DESCRIPTION', 'ADMISSION_STATUS_CODE', 'ADMISSION_SOURCE_DESCRIPTION', 'DISCHARGE_STATUS_CODE', 'VIZ_MSDRG_CODE', 'VIZ_MSDRG_DESCRIPTION', 'CMI', 'VIZ_BASEMSDRG_CODE', 'VIZ_BASEMSDRG_DESCRIPTION', 'LOS', 'ICU_DAYS', 'LOS_OUTLIER', 'DEATH_FLAG', 'RACE', 'ETHNICITY', 'SEX', 'READMIT_NUM', 'READMIT_DENOM', 'DAYS_TO_READMIT', 'OBSERVED_DIRECT_COST', 'COST_TYPE_CODE', 'RISK_TYPE_CODE', 'EXPECTED_LOS', 'EXPECTED_MORTALITY', 'EXPECTED_DIRECT_COST', 'RELATIVE_EXPECTED_MORTALITY', 'RELATIVE_EXPECTED_LOS', 'RELATIVE_EXPECTED_DIRECT_COST', 'VIZ_ACUITY_SCALE_MORTALITY', 'VIZ_ACUITY_SCALE_DIRECT_COST', 'VIZ_ACUITY_SCALE_LOS', 'VIZ_SERVICE_LINE_CODE', 'VIZ_SUB_SERVICE_LINE_CODE', 'VIZ_SERVICE_LINE_DESCRIPTION', 'VIZ_SUB_SERVICE_LINE_DESCRIPTION', 'SERVICE_LINE_VERSION', 'PRIMARY_DIAGNOSIS_CODE', 'PRIMARY_DIAGNOSIS_DESCRIPTION', 'PRIMARY_DIAGNOSIS', 'PRIMARY_PROCEDURE_CODE', 'PRIMARY_PROCEDURE_DESCRIPTION', 'PRIMARY_PROCEDURE', 'MORTALITY_QA_SERVICE_LINE', 'LOS_QA_SERVICE_LINE', 'READMIT_QA_SERVICE_LINE', 'NONVIABLE_NEONATE_FLAG', 'NORMAL_NEWBORN_FLAG', 'HOSPICE_FLAG', 'PLANNED_ADMISSION_FLAG', 'TRANSFER_IN_FLAG', 'PALLIATIVE_CARE_FLAG', 'RV_ADMIT_ED_TRAUMA', 'DISCHARGE_TO_HOSPICE_FLAG', 'RV_TXFER_ACUTE', 'DNR_WO_VENT_ECMO_FLAG', 'RV_VENT_ON_ADMIT_DATE', 'RV_FLUID_ELECTROLYTE_DISORDERS', 'RV_MALNUTRITION', 'RV_CHF', 'RV_SHOCK', 'RV_CACHEXIA', 'RV_COAGULATION_DEFECT', 'RV_METASTATIC_CANCER', 'RV_LIVER_FAILURE', 'RV_RESPIRATORY_FAILURE', 'RV_ACUTE_RENAL_FAILURE', 'RV_NUTRITIONAL_ANEMIA', 'RV_OBESITY', 'RV_ANEMIA_IN_CHRONIC_DISEASE', 'RV_DEMENTIA', 'RV_BLOOD_LOSS_ANEMIA', 'RV_ANEMIA', 'RV_THROMBOCYTOPENIA', 'RV_CHRONIC_FATIGUE', 'SUBSTANCE_ABUSE', 'ENC_COUNT', 'LENGTH_OF_STAY_DAYS', 'procedures']
#
# Sample structured row:
# {
#   "DATASET": "Focus",
#   "FACILITY_NAME": "WellStar Cobb Hospital",
#   "SHORTNAME": "WELLSTAR_COBB",
#   "VIZCOHORT": "COMM",
#   "VIZCOHORTLONG": "LSMC",
#   "PEER_GROUP": "CH",
#   "RECORD_ID": 7000000795,
#   "PAITENT_ID": "3T2GQWMAC7.25",
#   "ENCOUNTER_ID": 7429665188981.1,
#   "ADMISSION_DATE": "2025-10-17 00:00:00",
#   "DISCHARGE_DATE": "2025-10-18 00:00:00",
#   "DISCH_YEAR": 2025,
#   "DISCH_MONTH": 10,
#   "ADMISSION_AGE_YEARS": 65,
#   "ADMISSION_SOURCE_CODE": 52,
#   "ADMISSION_STATUS_DESCRIPTION": "Elective",
#   "ADMISSION_STATUS_CODE": 52,
#   "ADMISSION_SOURCE_DESCRIPTION": "Transfer from another health care facility",
#   "DISCHARGE_STATUS_CODE": 1,
#   "VIZ_MSDRG_CODE": 291,
#   "VIZ_MSDRG_DESCRIPTION": "Heart failure and shock with MCC",
#   "CMI": 0.94,
#   "VIZ_BASEMSDRG_CODE": 291,
#   "VIZ_BASEMSDRG_DESCRIPTION": "Heart failure and shock",
#   "LOS": 2,
#   "ICU_DAYS": 0,
#   "LOS_OUTLIER": 0,
#   "DEATH_FLAG": 0,
#   "RACE": "White",
#   "ETHNICITY": "Non Hispanic Origin",
#   "SEX": "Female",
#   "READMIT_NUM": NaN,
#   "READMIT_DENOM": NaN,
#   "DAYS_TO_READMIT": 11.0,
#   "OBSERVED_DIRECT_COST": 3269.36,
#   "COST_TYPE_CODE": 3,
#   "RISK_TYPE_CODE": 2,
#   "EXPECTED_LOS": 2.14,
#   "EXPECTED_MORTALITY": 0.0326,
#   "EXPECTED_DIRECT_COST": 2597.1,
#   "RELATIVE_EXPECTED_MORTALITY": 0.61,
#   "RELATIVE_EXPECTED_LOS": 0.93,
#   "RELATIVE_EXPECTED_DIRECT_COST": 1.26,
#   "VIZ_ACUITY_SCALE_MORTALITY": "Well Below",
#   "VIZ_ACUITY_SCALE_DIRECT_COST": "Above",
#   "VIZ_ACUITY_SCALE_LOS": "Slightly Below",
#   "VIZ_SERVICE_LINE_CODE": 9,
#   "VIZ_SUB_SERVICE_LINE_CODE": "9a",
#   "VIZ_SERVICE_LINE_DESCRIPTION": "Cardiology \u2014 Heart Failure",
#   "VIZ_SUB_SERVICE_LINE_DESCRIPTION": "Cardiology \u2014 CHF",
#   "SERVICE_LINE_VERSION": "2025Q4",
#   "PRIMARY_DIAGNOSIS_CODE": "E559",
#   "PRIMARY_DIAGNOSIS_DESCRIPTION": "Vitamin D deficiency, unspecified",
#   "PRIMARY_DIAGNOSIS": "Vitamin D deficiency",
#   "PRIMARY_PROCEDURE_CODE": "0DBP8ZX",
#   "PRIMARY_PROCEDURE_DESCRIPTION": "Diagnostic excision of large intestine, via natural or artificial opening endoscopic",
#   "PRIMARY_PROCEDURE": "Diagnostic excision of large intestine, via natural or artificial opening endoscopic",
#   "MORTALITY_QA_SERVICE_LINE": false,
#   "LOS_QA_SERVICE_LINE": false,
#   "READMIT_QA_SERVICE_LINE": false,
#   "NONVIABLE_NEONATE_FLAG": 0,
#   "NORMAL_NEWBORN_FLAG": 0,
#   "HOSPICE_FLAG": 0,
#   "PLANNED_ADMISSION_FLAG": 1,
#   "TRANSFER_IN_FLAG": 0,
#   "PALLIATIVE_CARE_FLAG": 0,
#   "RV_ADMIT_ED_TRAUMA": 0,
#   "DISCHARGE_TO_HOSPICE_FLAG": 0,
#   "RV_TXFER_ACUTE": 0,
#   "DNR_WO_VENT_ECMO_FLAG": 0,
#   "RV_VENT_ON_ADMIT_DATE": 0,
#   "RV_FLUID_ELECTROLYTE_DISORDERS": 0,
#   "RV_MALNUTRITION": 0,
#   "RV_CHF": 1,
#   "RV_SHOCK": 0,
#   "RV_CACHEXIA": 0,
#   "RV_COAGULATION_DEFECT": 0,
#   "RV_METASTATIC_CANCER": 0,
#   "RV_LIVER_FAILURE": 0,
#   "RV_RESPIRATORY_FAILURE": 0,
#   "RV_ACUTE_RENAL_FAILURE": 0,
#   "RV_NUTRITIONAL_ANEMIA": 0,
#   "RV_OBESITY": 0,
#   "RV_ANEMIA_IN_CHRONIC_DISEASE": 0,
#   "RV_DEMENTIA": 0,
#   "RV_BLOOD_LOSS_ANEMIA": 0,
#   "RV_ANEMIA": 0,
#   "RV_THROMBOCYTOPENIA": 0,
#   "RV_CHRONIC_FATIGUE": 0,
#   "SUBSTANCE_ABUSE": 0,
#   "ENC_COUNT": 1,
#   "LENGTH_OF_STAY_DAYS": 1,
#   "procedures": [
#     {
#       "code": "30233N1",
#       "sequence_number": 1,
#       "date": "2025-10-18",
#       "name": "Transfusion of nonautologous red blood cells into peripheral vein, percutaneous approach",
#       "variable_description": "Control Bleeding on Admission Day"
#     },
#     {
#       "code": "0W9G3ZZ",
#       "sequence_number": 2,
#       "date": "2025-10-17",
#       "name": "Drainage of thoracic cavity, percutaneous approach",
#       "variable_description": "Respiratory Support"
#     }
#   ]
# }
#
# Dropping 5 PROCEDURE_* columns
# Dropping 1 DIAGNOSIS_* columns
#
# Final shape: (2000, 93)
# Final columns: ['DATASET', 'FACILITY_NAME', 'SHORTNAME', 'VIZCOHORT', 'VIZCOHORTLONG', 'PEER_GROUP', 'RECORD_ID', 'PAITENT_ID', 'ENCOUNTER_ID', 'ADMISSION_DATE', 'DISCHARGE_DATE', 'DISCH_YEAR', 'DISCH_MONTH', 'ADMISSION_AGE_YEARS', 'ADMISSION_SOURCE_CODE', 'ADMISSION_STATUS_DESCRIPTION', 'ADMISSION_STATUS_CODE', 'ADMISSION_SOURCE_DESCRIPTION', 'DISCHARGE_STATUS_CODE', 'VIZ_MSDRG_CODE', 'VIZ_MSDRG_DESCRIPTION', 'CMI', 'VIZ_BASEMSDRG_CODE', 'VIZ_BASEMSDRG_DESCRIPTION', 'LOS', 'ICU_DAYS', 'LOS_OUTLIER', 'DEATH_FLAG', 'RACE', 'ETHNICITY', 'SEX', 'READMIT_NUM', 'READMIT_DENOM', 'DAYS_TO_READMIT', 'OBSERVED_DIRECT_COST', 'COST_TYPE_CODE', 'RISK_TYPE_CODE', 'EXPECTED_LOS', 'EXPECTED_MORTALITY', 'EXPECTED_DIRECT_COST', 'RELATIVE_EXPECTED_MORTALITY', 'RELATIVE_EXPECTED_LOS', 'RELATIVE_EXPECTED_DIRECT_COST', 'VIZ_ACUITY_SCALE_MORTALITY', 'VIZ_ACUITY_SCALE_DIRECT_COST', 'VIZ_ACUITY_SCALE_LOS', 'VIZ_SERVICE_LINE_CODE', 'VIZ_SUB_SERVICE_LINE_CODE', 'VIZ_SERVICE_LINE_DESCRIPTION', 'VIZ_SUB_SERVICE_LINE_DESCRIPTION', 'SERVICE_LINE_VERSION', 'PRIMARY_DIAGNOSIS_CODE', 'PRIMARY_DIAGNOSIS_DESCRIPTION', 'PRIMARY_DIAGNOSIS', 'PRIMARY_PROCEDURE_CODE', 'PRIMARY_PROCEDURE_DESCRIPTION', 'PRIMARY_PROCEDURE', 'MORTALITY_QA_SERVICE_LINE', 'LOS_QA_SERVICE_LINE', 'READMIT_QA_SERVICE_LINE', 'NONVIABLE_NEONATE_FLAG', 'NORMAL_NEWBORN_FLAG', 'HOSPICE_FLAG', 'PLANNED_ADMISSION_FLAG', 'TRANSFER_IN_FLAG', 'PALLIATIVE_CARE_FLAG', 'RV_ADMIT_ED_TRAUMA', 'DISCHARGE_TO_HOSPICE_FLAG', 'RV_TXFER_ACUTE', 'DNR_WO_VENT_ECMO_FLAG', 'RV_VENT_ON_ADMIT_DATE', 'RV_FLUID_ELECTROLYTE_DISORDERS', 'RV_MALNUTRITION', 'RV_CHF', 'RV_SHOCK', 'RV_CACHEXIA', 'RV_COAGULATION_DEFECT', 'RV_METASTATIC_CANCER', 'RV_LIVER_FAILURE', 'RV_RESPIRATORY_FAILURE', 'RV_ACUTE_RENAL_FAILURE', 'RV_NUTRITIONAL_ANEMIA', 'RV_OBESITY', 'RV_ANEMIA_IN_CHRONIC_DISEASE', 'RV_DEMENTIA', 'RV_BLOOD_LOSS_ANEMIA', 'RV_ANEMIA', 'RV_THROMBOCYTOPENIA', 'RV_CHRONIC_FATIGUE', 'SUBSTANCE_ABUSE', 'ENC_COUNT', 'LENGTH_OF_STAY_DAYS', 'procedures']
#
# Sample structured row:
# {
#   "DATASET": "Focus",
#   "FACILITY_NAME": "WellStar Cobb Hospital",
#   "SHORTNAME": "WELLSTAR_COBB",
#   "VIZCOHORT": "COMM",
#   "VIZCOHORTLONG": "LSMC",
#   "PEER_GROUP": "CH",
#   "RECORD_ID": 7000000795,
#   "PAITENT_ID": "3T2GQWMAC7.25",
#   "ENCOUNTER_ID": 7429665188981.1,
#   "ADMISSION_DATE": "2025-10-17 00:00:00",
#   "DISCHARGE_DATE": "2025-10-18 00:00:00",
#   "DISCH_YEAR": 2025,
#   "DISCH_MONTH": 10,
#   "ADMISSION_AGE_YEARS": 65,
#   "ADMISSION_SOURCE_CODE": 52,
#   "ADMISSION_STATUS_DESCRIPTION": "Elective",
#   "ADMISSION_STATUS_CODE": 52,
#   "ADMISSION_SOURCE_DESCRIPTION": "Transfer from another health care facility",
#   "DISCHARGE_STATUS_CODE": 1,
#   "VIZ_MSDRG_CODE": 291,
#   "VIZ_MSDRG_DESCRIPTION": "Heart failure and shock with MCC",
#   "CMI": 0.94,
#   "VIZ_BASEMSDRG_CODE": 291,
#   "VIZ_BASEMSDRG_DESCRIPTION": "Heart failure and shock",
#   "LOS": 2,
#   "ICU_DAYS": 0,
#   "LOS_OUTLIER": 0,
#   "DEATH_FLAG": 0,
#   "RACE": "White",
#   "ETHNICITY": "Non Hispanic Origin",
#   "SEX": "Female",
#   "READMIT_NUM": NaN,
#   "READMIT_DENOM": NaN,
#   "DAYS_TO_READMIT": 11.0,
#   "OBSERVED_DIRECT_COST": 3269.36,
#   "COST_TYPE_CODE": 3,
#   "RISK_TYPE_CODE": 2,
#   "EXPECTED_LOS": 2.14,
#   "EXPECTED_MORTALITY": 0.0326,
#   "EXPECTED_DIRECT_COST": 2597.1,
#   "RELATIVE_EXPECTED_MORTALITY": 0.61,
#   "RELATIVE_EXPECTED_LOS": 0.93,
#   "RELATIVE_EXPECTED_DIRECT_COST": 1.26,
#   "VIZ_ACUITY_SCALE_MORTALITY": "Well Below",
#   "VIZ_ACUITY_SCALE_DIRECT_COST": "Above",
#   "VIZ_ACUITY_SCALE_LOS": "Slightly Below",
#   "VIZ_SERVICE_LINE_CODE": 9,
#   "VIZ_SUB_SERVICE_LINE_CODE": "9a",
#   "VIZ_SERVICE_LINE_DESCRIPTION": "Cardiology \u2014 Heart Failure",
#   "VIZ_SUB_SERVICE_LINE_DESCRIPTION": "Cardiology \u2014 CHF",
#   "SERVICE_LINE_VERSION": "2025Q4",
#   "PRIMARY_DIAGNOSIS_CODE": "E559",
#   "PRIMARY_DIAGNOSIS_DESCRIPTION": "Vitamin D deficiency, unspecified",
#   "PRIMARY_DIAGNOSIS": "Vitamin D deficiency",
#   "PRIMARY_PROCEDURE_CODE": "0DBP8ZX",
#   "PRIMARY_PROCEDURE_DESCRIPTION": "Diagnostic excision of large intestine, via natural or artificial opening endoscopic",
#   "PRIMARY_PROCEDURE": "Diagnostic excision of large intestine, via natural or artificial opening endoscopic",
#   "MORTALITY_QA_SERVICE_LINE": false,
#   "LOS_QA_SERVICE_LINE": false,
#   "READMIT_QA_SERVICE_LINE": false,
#   "NONVIABLE_NEONATE_FLAG": 0,
#   "NORMAL_NEWBORN_FLAG": 0,
#   "HOSPICE_FLAG": 0,
#   "PLANNED_ADMISSION_FLAG": 1,
#   "TRANSFER_IN_FLAG": 0,
#   "PALLIATIVE_CARE_FLAG": 0,
#   "RV_ADMIT_ED_TRAUMA": 0,
#   "DISCHARGE_TO_HOSPICE_FLAG": 0,
#   "RV_TXFER_ACUTE": 0,
#   "DNR_WO_VENT_ECMO_FLAG": 0,
#   "RV_VENT_ON_ADMIT_DATE": 0,
#   "RV_FLUID_ELECTROLYTE_DISORDERS": 0,
#   "RV_MALNUTRITION": 0,
#   "RV_CHF": 1,
#   "RV_SHOCK": 0,
#   "RV_CACHEXIA": 0,
#   "RV_COAGULATION_DEFECT": 0,
#   "RV_METASTATIC_CANCER": 0,
#   "RV_LIVER_FAILURE": 0,
#   "RV_RESPIRATORY_FAILURE": 0,
#   "RV_ACUTE_RENAL_FAILURE": 0,
#   "RV_NUTRITIONAL_ANEMIA": 0,
#   "RV_OBESITY": 0,
#   "RV_ANEMIA_IN_CHRONIC_DISEASE": 0,
#   "RV_DEMENTIA": 0,
#   "RV_BLOOD_LOSS_ANEMIA": 0,
#   "RV_ANEMIA": 0,
#   "RV_THROMBOCYTOPENIA": 0,
#   "RV_CHRONIC_FATIGUE": 0,
#   "SUBSTANCE_ABUSE": 0,
#   "ENC_COUNT": 1,
#   "LENGTH_OF_STAY_DAYS": 1,
#   "procedures": [
#     {
#       "code": "30233N1",
#       "sequence_number": 1,
#       "date": "2025-10-18",
#       "name": "Transfusion of nonautologous red blood cells into peripheral vein, percutaneous approach",
#       "variable_description": "Control Bleeding on Admission Day"
#     },
#     {
#       "code": "0W9G3ZZ",
#       "sequence_number": 2,
#       "date": "2025-10-17",
#       "name": "Drainage of thoracic cavity, percutaneous approach",
#       "variable_description": "Respiratory Support"
#     }
#   ]
# }

# %%
# Sort procedures by sequence number ascending
def sort_procedures_by_sequence(procedures_list):
    """Sort procedures by sequence_number in ascending order."""
    if not procedures_list or len(procedures_list) == 0:
        return procedures_list
    
    # Check if sequence_number exists in the first item
    if 'sequence_number' not in procedures_list[0]:
        return procedures_list
    
    try:
        # Sort by sequence_number, handling None values by putting them at the end
        sorted_procedures = sorted(
            procedures_list, 
            key=lambda x: (x.get('sequence_number') is None, x.get('sequence_number') if x.get('sequence_number') is not None else float('inf'))
        )
        return sorted_procedures
    except:
        # If sorting fails, return original list
        return procedures_list

print("Sorting procedures by sequence number...")
final_df_structured['procedures'] = final_df_structured['procedures'].apply(sort_procedures_by_sequence)

# Save the structured dataframe to JSON
output_file = 'processed_structured.json'

print(f"\nSaving structured data to {output_file}...")
final_df_structured.to_json(output_file, orient='records', indent=2, date_format='iso')

print(f"✓ Saved {len(final_df_structured)} records to {output_file}")

# Show statistics
print("\n" + "=" * 80)
print("STATISTICS")
print("=" * 80)

print(f"\nTotal records: {len(final_df_structured)}")
print(f"Total columns: {len(final_df_structured.columns)}")
# Out:
# Sorting procedures by sequence number...
#
# Saving structured data to processed_structured.json...
# ✓ Saved 2000 records to processed_structured.json
#
# ================================================================================
# STATISTICS
# ================================================================================
#
# Total records: 2000
# Total columns: 93

# %%
# Out:
# Index(['DATASET', 'FACILITY_NAME', 'SHORTNAME', 'VIZCOHORT', 'VIZCOHORTLONG',
#        'PEER_GROUP', 'RECORD_ID', 'PAITENT_ID', 'ENCOUNTER_ID',
#        'ADMISSION_DATE', 'DISCHARGE_DATE', 'DISCH_YEAR', 'DISCH_MONTH',
#        'ADMISSION_AGE_YEARS', 'ADMISSION_SOURCE_CODE',
#        'ADMISSION_STATUS_DESCRIPTION', 'ADMISSION_STATUS_CODE',
#        'ADMISSION_SOURCE_DESCRIPTION', 'DISCHARGE_STATUS_CODE',
#        'VIZ_MSDRG_CODE', 'VIZ_MSDRG_DESCRIPTION', 'CMI', 'VIZ_BASEMSDRG_CODE',
#        'VIZ_BASEMSDRG_DESCRIPTION', 'LOS', 'ICU_DAYS', 'LOS_OUTLIER',
#        'DEATH_FLAG', 'RACE', 'ETHNICITY', 'SEX', 'READMIT_NUM',
#        'READMIT_DENOM', 'DAYS_TO_READMIT', 'OBSERVED_DIRECT_COST',
#        'COST_TYPE_CODE', 'RISK_TYPE_CODE', 'EXPECTED_LOS',
#        'EXPECTED_MORTALITY', 'EXPECTED_DIRECT_COST',
#        'RELATIVE_EXPECTED_MORTALITY', 'RELATIVE_EXPECTED_LOS',
#        'RELATIVE_EXPECTED_DIRECT_COST', 'VIZ_ACUITY_SCALE_MORTALITY',
#        'VIZ_ACUITY_SCALE_DIRECT_COST', 'VIZ_ACUITY_SCALE_LOS',
#        'VIZ_SERVICE_LINE_CODE', 'VIZ_SUB_SERVICE_LINE_CODE',
#        'VIZ_SERVICE_LINE_DESCRIPTION', 'VIZ_SUB_SERVICE_LINE_DESCRIPTION',
#        'SERVICE_LINE_VERSION', 'PRIMARY_DIAGNOSIS_CODE',
#        'PRIMARY_DIAGNOSIS_DESCRIPTION', 'PRIMARY_DIAGNOSIS',
#        'PRIMARY_PROCEDURE_CODE', 'PRIMARY_PROCEDURE_DESCRIPTION',
#        'PRIMARY_PROCEDURE', 'MORTALITY_QA_SERVICE_LINE', 'LOS_QA_SERVICE_LINE',
#        'READMIT_QA_SERVICE_LINE', 'NONVIABLE_NEONATE_FLAG',
#        'NORMAL_NEWBORN_FLAG', 'HOSPICE_FLAG', 'PLANNED_ADMISSION_FLAG',
#        'TRANSFER_IN_FLAG', 'PALLIATIVE_CARE_FLAG', 'RV_ADMIT_ED_TRAUMA',
#        'DISCHARGE_TO_HOSPICE_FLAG', 'RV_TXFER_ACUTE', 'DNR_WO_VENT_ECMO_FLAG',
#        'RV_VENT_ON_ADMIT_DATE', 'RV_FLUID_ELECTROLYTE_DISORDERS',
#        'RV_MALNUTRITION', 'RV_CHF', 'RV_SHOCK', 'RV_CACHEXIA',
#        'RV_COAGULATION_DEFECT', 'RV_METASTATIC_CANCER', 'RV_LIVER_FAILURE',
#        'RV_RESPIRATORY_FAILURE', 'RV_ACUTE_RENAL_FAILURE',
#        'RV_NUTRITIONAL_ANEMIA', 'RV_OBESITY', 'RV_ANEMIA_IN_CHRONIC_DISEASE',
#        'RV_DEMENTIA', 'RV_BLOOD_LOSS_ANEMIA', 'RV_ANEMIA',
#        'RV_THROMBOCYTOPENIA', 'RV_CHRONIC_FATIGUE', 'SUBSTANCE_ABUSE',
#        'ENC_COUNT', 'LENGTH_OF_STAY_DAYS', 'procedures'],
#       dtype='object')
